# %% [markdown]
# # THIS AN ANALYSIS ON  CUSTOMERS FOR A SUPERMARKET WITH THREE(3) BRANCHES

# %%
# importing necessary Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://bit.ly/3lLgXwC'
data = pd.read_csv(url)
data
# Out:
#       invoice_id branch customer_type  gender            product_line  \
# 0    750-67-8428      A        Member  Female       Health and beauty
# 1    226-31-3081      C        Normal  Female  Electronic accessories
# 2    631-41-3108      A        Normal    Male      Home and lifestyle
# 3    123-19-1176      A        Member    Male       Health and beauty
# 4    373-73-7910      A        Normal    Male       Sports and travel
# ..           ...    ...           ...     ...                     ...
# 995  233-67-5758      C        Normal    Male       Health and beauty
# 996  303-96-2227      B        Normal  Female      Home and lifestyle
# 997  727-02-1313      A        Member    Male      Food and beverages
# 998  347-56-2442      A        Normal    Male      Home and lifestyle
# 999  849-09-3807      A        Member  Female     Fashion accessories
#
#      unit_price  quantity  tax_5_perc      total       date   time  \
# ...

# %% [markdown]
# # EXPLORING DATA SET

# %%
# reviewing the first 5 records
data.head(n=5)
# Out:
#     invoice_id branch customer_type  gender            product_line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
#
#    unit_price  quantity  tax_5_perc     total       date   time       payment  \
# 0       74.69         7     26.1415  548.9715   1/5/2019  13:08  Mobile Money
# 1       15.28         5      3.8200   80.2200   3/8/2019  10:29          Cash
# 2       46.33         7     16.2155  340.5255   3/3/2019  13:23    Debit card
# 3       58.22         8     23.2880  489.0480  1/27/2019  20:33  Mobile Money
# 4       86.31         7     30.2085  634.3785   2/8/2019  10:37  Mobile Money
#
#    cost_of_goods_sold  gross_margin_percentage  gross_income  rating
# ...

# %%
# reviewing the last 5 records
data.tail(n=5)
# Out:
#       invoice_id branch customer_type  gender         product_line  \
# 995  233-67-5758      C        Normal    Male    Health and beauty
# 996  303-96-2227      B        Normal  Female   Home and lifestyle
# 997  727-02-1313      A        Member    Male   Food and beverages
# 998  347-56-2442      A        Normal    Male   Home and lifestyle
# 999  849-09-3807      A        Member  Female  Fashion accessories
#
#      unit_price  quantity  tax_5_perc      total       date   time  \
# 995       40.35         1      2.0175    42.3675  1/29/2019  13:46
# 996       97.38        10     48.6900  1022.4900   3/2/2019  17:16
# 997       31.84         1      1.5920    33.4320   2/9/2019  13:22
# 998       65.82         1      3.2910    69.1110  2/22/2019  15:33
# 999       88.34         7     30.9190   649.2990  2/18/2019  13:28
#
#           payment  cost_of_goods_sold  gross_margin_percentage  gross_income  \
# 995  Mobile Money               40.35                 4.761905        2.0175
# ...

# %% [markdown]
# # This shows the data sheet size

# %%
data.shape
# Out:
# (1000, 16)

# %%
data.columns
# Out:
# Index(['invoice_id', 'branch', 'customer_type', 'gender', 'product_line',
#        'unit_price', 'quantity', 'tax_5_perc', 'total', 'date', 'time',
#        'payment', 'cost_of_goods_sold', 'gross_margin_percentage',
#        'gross_income', 'rating'],
#       dtype='object')

# %%
# reviewing the data types of the features/variables/columns
data.dtypes
# Out:
# invoice_id                  object
# branch                      object
# customer_type               object
# gender                      object
# product_line                object
# unit_price                 float64
# quantity                     int64
# tax_5_perc                 float64
# total                      float64
# date                        object
# time                        object
# payment                     object
# cost_of_goods_sold         float64
# gross_margin_percentage    float64
# gross_income               float64
# rating                     float64
# dtype: object

# %%
# looking for duplicated records
data.duplicated().any()
# Out:
# False

# %%
# looking for missing values
data.isna()
# Out:
#      invoice_id  branch  customer_type  gender  product_line  unit_price  \
# 0         False   False          False   False         False       False
# 1         False   False          False   False         False       False
# 2         False   False          False   False         False       False
# 3         False   False          False   False         False       False
# 4         False   False          False   False         False       False
# ..          ...     ...            ...     ...           ...         ...
# 995       False   False          False   False         False       False
# 996       False   False          False   False         False       False
# 997       False   False          False   False         False       False
# 998       False   False          False   False         False       False
# 999       False   False          False   False         False       False
#
#      quantity  tax_5_perc  total   date   time  payment  cost_of_goods_sold  \
# ...

# %%
data.isna().sum()
# Out:
# invoice_id                 0
# branch                     0
# customer_type              0
# gender                     0
# product_line               0
# unit_price                 0
# quantity                   0
# tax_5_perc                 0
# total                      0
# date                       0
# time                       0
# payment                    0
# cost_of_goods_sold         0
# gross_margin_percentage    0
# gross_income               0
# rating                     0
# dtype: int64

# %%
# A summary statistics (descriptive statistics) of the numerical varables
data.describe()
# Out:
#         unit_price     quantity   tax_5_perc        total  cost_of_goods_sold  \
# count  1000.000000  1000.000000  1000.000000  1000.000000          1000.00000
# mean     55.672130     5.510000    15.379369   322.966749           307.58738
# std      26.494628     2.923431    11.708825   245.885335           234.17651
# min      10.080000     1.000000     0.508500    10.678500            10.17000
# 25%      32.875000     3.000000     5.924875   124.422375           118.49750
# 50%      55.230000     5.000000    12.088000   253.848000           241.76000
# 75%      77.935000     8.000000    22.445250   471.350250           448.90500
# max      99.960000    10.000000    49.650000  1042.650000           993.00000
#
#        gross_margin_percentage  gross_income      rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# ...

# %%
#A bar plot of the 'branch' variable
plt.figure(figsize = (8, 4))
data.branch.value_counts().plot(kind = 'bar', rot = 0, color = ['red', 'green', 'blue'])
plt.xlabel('Branch')
plt.title('Distribution of Branches')
plt.show()

# %%
#  A bar plot of the 'customer_type' variable
plt.figure(figsize = (4, 6))
data.customer_type.value_counts().plot(kind = 'bar', rot = 0, color = ['red', 'green'])
plt.xlabel('Customer Type')
plt.title('Distribution of Customer Type')
plt.show()

# %%
# get the value counts of the 'customer_type' variable
data.customer_type.value_counts()
# Out:
# Member    501
# Normal    499
# Name: customer_type, dtype: int64

# %%
# get the value counts of the 'gender' variable
data.gender.value_counts()
# Out:
# Female    501
# Male      499
# Name: gender, dtype: int64

# %%
# A bar plot of the 'product_line' variable
plt.figure(figsize = (8, 4))
data.product_line.value_counts().plot(kind = 'bar', rot = 15, 
                                   color = sns.color_palette('rocket', data.product_line.nunique()))
plt.xlabel('Product Line')
plt.title('Distribution of Product Line')
plt.xticks(ha = 'right')
plt.show()

# %%
#A pie chart of the 'payment' variable
plt.figure(figsize = (8, 6))
data.payment.value_counts().plot(kind = 'pie', autopct = '%1.1f%%')
plt.title('Distribution of Method of Payment')
plt.show()

# %%
# Heatmap of the correlations of the variables in the dataset
corr = data.corr()
fig, ax = plt.subplots(figsize = (10, 10))
colormap = sns.diverging_palette(220, 10, as_cmap = True)
sns.heatmap(corr, cmap = colormap, annot = True, fmt = ".2f")
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
# A pivot table to find the mean of gross income per branch
import numpy as np
data.head()
pd.pivot_table(data, index=['branch'], aggfunc={'gross_income': np.mean})
# Out:
#         gross_income
# branch
# A          14.874001
# B          15.232024
# C          16.052367

# %%
# A pivot table to find the average gross income per product line
pd.pivot_table(data, index=['product_line'], aggfunc={'gross_income': np.average})
# Out:
#                         gross_income
# product_line
# Electronic accessories     15.220597
# Fashion accessories        14.528062
# Food and beverages         15.365310
# Health and beauty          15.411572
# Home and lifestyle         16.030331
# Sports and travel          15.812630

# %%
#The average gross income per product line for each branch
branches = pd.pivot_table(data, index=['branch', 'product_line'], aggfunc={'gross_income' : 'mean'})
branches = branches.reset_index()
branches
# Out:
#    branch            product_line  gross_income
# 0       A  Electronic accessories     14.537392
# 1       A     Fashion accessories     15.249775
# 2       A      Food and beverages     14.091216
# 3       A       Health and beauty     12.763681
# 4       A      Home and lifestyle     16.422854
# 5       A       Sports and travel     15.635754
# 6       B  Electronic accessories     14.763155
# 7       B     Fashion accessories     12.606234
# 8       B      Food and beverages     14.490370
# 9       B       Health and beauty     17.952075
# 10      B      Home and lifestyle     16.713490
# 11      B       Sports and travel     15.351919
# 12      C  Electronic accessories     16.423355
# 13      C     Fashion accessories     15.794923
# 14      C      Food and beverages     17.147803
# 15      C       Health and beauty     15.215500
# 16      C      Home and lifestyle     14.704289
# 17      C       Sports and travel     16.679289

# %%
# The average gross income per product line for Branch A
branch_a = branches.loc[branches['branch'] == 'A']
branch_a
# Out:
#   branch            product_line  gross_income
# 0      A  Electronic accessories     14.537392
# 1      A     Fashion accessories     15.249775
# 2      A      Food and beverages     14.091216
# 3      A       Health and beauty     12.763681
# 4      A      Home and lifestyle     16.422854
# 5      A       Sports and travel     15.635754

# %%
# The average gross income per product line for Branch B
branch_b = branches.loc[branches['branch'] == 'B']
branch_b
# Out:
#    branch            product_line  gross_income
# 6       B  Electronic accessories     14.763155
# 7       B     Fashion accessories     12.606234
# 8       B      Food and beverages     14.490370
# 9       B       Health and beauty     17.952075
# 10      B      Home and lifestyle     16.713490
# 11      B       Sports and travel     15.351919

# %%
#The average gross income per product line for Branch C
branch_c = branches.loc[branches['branch'] == 'C']
branch_c
# Out:
#    branch            product_line  gross_income
# 12      C  Electronic accessories     16.423355
# 13      C     Fashion accessories     15.794923
# 14      C      Food and beverages     17.147803
# 15      C       Health and beauty     15.215500
# 16      C      Home and lifestyle     14.704289
# 17      C       Sports and travel     16.679289

# %%
# A pivot table to find the average rating per branch
ratings_branch = pd.pivot_table(data, index=['branch',], aggfunc={'rating' : 'mean'})
ratings_branch
# Out:
#           rating
# branch
# A       7.027059
# B       6.818072
# C       7.072866

# %%
#A pivot table to find the average rating per product_line
ratings_product_line = pd.pivot_table(data, index=['product_line',], aggfunc={'rating' : 'mean'})
ratings_product_line
# Out:
#                           rating
# product_line
# Electronic accessories  6.924706
# Fashion accessories     7.029213
# Food and beverages      7.113218
# Health and beauty       7.003289
# Home and lifestyle      6.837500
# Sports and travel       6.916265

# %%
#  Average rating per product line for each branch
ratings = pd.pivot_table(data, index=['branch', 'product_line'], aggfunc={'rating' : 'mean'})
ratings = ratings.reset_index()
ratings
# Out:
#    branch            product_line    rating
# 0       A  Electronic accessories  6.911667
# 1       A     Fashion accessories  6.878431
# 2       A      Food and beverages  7.253448
# 3       A       Health and beauty  6.900000
# 4       A      Home and lifestyle  6.930769
# 5       A       Sports and travel  7.257627
# 6       B  Electronic accessories  7.116364
# 7       B     Fashion accessories  6.722581
# 8       B      Food and beverages  6.994000
# 9       B       Health and beauty  7.100000
# 10      B      Home and lifestyle  6.516000
# 11      B       Sports and travel  6.509677
# 12      C  Electronic accessories  6.747273
# 13      C     Fashion accessories  7.440000
# 14      C      Food and beverages  7.080303
# 15      C       Health and beauty  6.998077
# 16      C      Home and lifestyle  7.060000
# 17      C       Sports and travel  7.028889

# %%
# A pivot table to find the average rating perproduct_line per branch
ratings_a = ratings.loc[ratings['branch'] == 'A']
ratings_a
# Out:
#   branch            product_line    rating
# 0      A  Electronic accessories  6.911667
# 1      A     Fashion accessories  6.878431
# 2      A      Food and beverages  7.253448
# 3      A       Health and beauty  6.900000
# 4      A      Home and lifestyle  6.930769
# 5      A       Sports and travel  7.257627

# %%
# A pivot table to find the average rating perproduct_line per branch
ratings_b = ratings.loc[ratings['branch'] == 'B']
ratings_b
# Out:
#    branch            product_line    rating
# 6       B  Electronic accessories  7.116364
# 7       B     Fashion accessories  6.722581
# 8       B      Food and beverages  6.994000
# 9       B       Health and beauty  7.100000
# 10      B      Home and lifestyle  6.516000
# 11      B       Sports and travel  6.509677

# %%
# A pivot table to find the average rating perproduct_line per branch
ratings_c = ratings.loc[ratings['branch'] == 'C']
ratings_c
# Out:
#    branch            product_line    rating
# 12      C  Electronic accessories  6.747273
# 13      C     Fashion accessories  7.440000
# 14      C      Food and beverages  7.080303
# 15      C       Health and beauty  6.998077
# 16      C      Home and lifestyle  7.060000
# 17      C       Sports and travel  7.028889
